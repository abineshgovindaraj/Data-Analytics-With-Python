# %% [markdown]
# ## Import The Required Modules

# %%
import requests
import time
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## See The Structure Of URL

# %%
#https://www.flipkart.com/search?q=macbook&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=macbook%7CLaptops&requestId=725f153c-36bb-478c-8f10-e54c60187a13&as-backfill=on&page=1
#https://www.flipkart.com/search?q=macbook&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=macbook%7CLaptops&requestId=725f153c-36bb-478c-8f10-e54c60187a13&as-backfill=on&page=2

# %%
base_url = 'https://www.flipkart.com/search?q=iphone%2011&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'

# %% [markdown]
# ## Create List For Store The Data

# %%
pd_name = []
price =[]
ratings = []
warranty = []
ratingsno = []
reviewsno = []
features = []
for i in range(1,3):
  time.sleep(3)
  req = requests.get(base_url+str(i))
  soup = BeautifulSoup(req.text,'html')

  #product name
  pdt_name = soup.findAll('div',attrs={'class':'_4rR01T'})
  [pd_name.append(i.text) for i in pdt_name]

  #price
  p = soup.findAll('div',attrs={'class':'_30jeq3 _1_WHN1'})
  [price.append(i.text) for i in p]

  #ratings
  r = soup.findAll('div',attrs={'class':'gUuXy-'})
  [ratings.append(i.span.div.text) for i in r]

  #warranty
  wl = soup.findAll('ul',attrs={'class':'_1xgFaf'})
  w = [i.findAll('li')[-1] for i in wl]
  [warranty.append(i.text) for i in w]

  #number of ratings and reviews
  a = soup.findAll('span',attrs={'class':'_2_R_DZ'})
  for i in a:
    a = i.text.split('&')
    ratingsno.append(a[0].split(" ")[0])
    reviewsno.append(a[1].split(" ")[0])

  #features
  prop = soup.findAll('ul',attrs={'class':'_1xgFaf'})
  for i in prop:
    a = i.findAll('li')[0:-2]
    b =[i.text for i in a]
    features.append(','.join(b))

# %%
print('pd_name= ',len(pd_name))
print('price = ',len(price))
print('ratings = ',len(ratings))
print('warranty = ',len(warranty))
print('ratingsno =',len(ratingsno))
print('reviewsno = ',len(reviewsno))
print('features = ',len(features))
# Out:
# pd_name=  48
# price =  48
# ratings =  48
# warranty =  48
# ratingsno = 48
# reviewsno =  48
# features =  48

# %%
data = pd.DataFrame({'Product':pd_name,
                     'Price':price,
                     'Ratings':ratings,
                     'Warranty':warranty,
                     'No of Ratings':ratingsno,
                     'No of Reviews':reviewsno,
                     'Features':features})
data
# Out:
#                                               Product    Price Ratings  \
# 0                      APPLE iPhone 11 (White, 64 GB)  ₹46,999     4.6
# 1                     APPLE iPhone 11 (Purple, 64 GB)  ₹46,999     4.6
# 2                     APPLE iPhone 11 (White, 128 GB)  ₹51,999     4.6
# 3                      APPLE iPhone 11 (Green, 64 GB)  ₹46,999     4.6
# 4                    APPLE iPhone 11 (Purple, 128 GB)  ₹51,999     4.6
# 5                        APPLE iPhone 11 (Red, 64 GB)  ₹46,999     4.6
# 6                       APPLE iPhone 11 (Red, 128 GB)  ₹51,999     4.6
# 7                     APPLE iPhone 11 (Black, 128 GB)  ₹51,999     4.6
# 8                      APPLE iPhone 11 (Black, 64 GB)  ₹46,999     4.6
# 9                     APPLE iPhone 11 (Green, 128 GB)  ₹51,999     4.6
# 10                    APPLE iPhone 11 (Yellow, 64 GB)  ₹46,999     4.6
# 11                   APPLE iPhone 11 (Yellow, 128 GB)  ₹51,999     4.6
# 12                       APPLE iPhone 6 (Gold, 32 GB)  ₹30,780     4.4
# 13  Apple iPhone 11 (White, 64 GB) (Includes EarPo...  ₹49,900     4.6
# 14  Apple iPhone 11 (Purple, 64 GB) (Includes EarP...  ₹49,900     4.6
# 15  Apple iPhone 11 (Black, 256 GB) (Includes EarP...  ₹64,900     4.6
# 16  Apple iPhone 11 (Red, 128 GB) (Includes EarPod...  ₹54,900     4.6
# 17  Apple iPhone 11 (White, 256 GB) (Includes EarP...  ₹64,900     4.6
# 18  Apple iPhone 11 (Yellow, 256 GB) (Includes Ear...  ₹64,900     4.6
# 19                    APPLE iPhone 11 (Green, 256 GB)  ₹64,900     4.6
# 20  Apple iPhone 11 (Yellow, 128 GB) (Includes Ear...  ₹54,900     4.6
# 21  Apple iPhone 11 (Green, 64 GB) (Includes EarPo...  ₹49,900     4.6
# 22  Apple iPhone 11 (Green, 128 GB) (Includes EarP...  ₹54,900     4.6
# 23  Apple iPhone 11 (White, 128 GB) (Includes EarP...  ₹54,900     4.6
# 24                     APPLE iPhone 11 (White, 64 GB)  ₹46,999     4.6
# 25                    APPLE iPhone 11 (Purple, 64 GB)  ₹46,999     4.6
# 26                     APPLE iPhone 11 (Green, 64 GB)  ₹46,999     4.6
# 27                    APPLE iPhone 11 (White, 128 GB)  ₹51,999     4.6
# 28                       APPLE iPhone 11 (Red, 64 GB)  ₹46,999     4.6
# 29                   APPLE iPhone 11 (Purple, 128 GB)  ₹51,999     4.6
# 30                     APPLE iPhone 11 (Black, 64 GB)  ₹46,999     4.6
# 31                      APPLE iPhone 11 (Red, 128 GB)  ₹51,999     4.6
# 32                    APPLE iPhone 11 (Green, 128 GB)  ₹51,999     4.6
# 33                    APPLE iPhone 11 (Black, 128 GB)  ₹51,999     4.6
# 34                    APPLE iPhone 11 (Yellow, 64 GB)  ₹46,999     4.6
# 35                   APPLE iPhone 11 (Yellow, 128 GB)  ₹51,999     4.6
# 36                 APPLE iPhone 6 (Space Grey, 16 GB)  ₹51,999     4.4
# 37  Apple iPhone 11 (White, 64 GB) (Includes EarPo...  ₹49,900     4.6
# 38  Apple iPhone 11 (Red, 64 GB) (Includes EarPods...  ₹49,900     4.6
# 39  Apple iPhone 11 (Purple, 64 GB) (Includes EarP...  ₹49,900     4.6
# 40  Apple iPhone 11 (Black, 256 GB) (Includes EarP...  ₹64,900     4.6
# 41  Apple iPhone 11 (Red, 128 GB) (Includes EarPod...  ₹54,900     4.6
# 42  Apple iPhone 11 (Yellow, 256 GB) (Includes Ear...  ₹64,900     4.6
# 43  Apple iPhone 11 (White, 256 GB) (Includes EarP...  ₹64,900     4.6
# 44                    APPLE iPhone 11 (Green, 256 GB)  ₹64,900     4.6
# 45  Apple iPhone 11 (Yellow, 128 GB) (Includes Ear...  ₹54,900     4.6
# 46  Apple iPhone 11 (Green, 128 GB) (Includes EarP...  ₹54,900     4.6
# 47  Apple iPhone 11 (Green, 64 GB) (Includes EarPo...  ₹49,900     4.6
#
#                         Warranty No of Ratings No of Reviews  \
# 0       Brand Warranty of 1 Year        85,171         6,433
# 1       Brand Warranty of 1 Year        85,171         6,433
# 2       Brand Warranty of 1 Year        85,171         6,433
# 3       Brand Warranty of 1 Year        85,171         6,433
# 4       Brand Warranty of 1 Year        85,171         6,433
# 5       Brand Warranty of 1 Year        85,171         6,433
# 6       Brand Warranty of 1 Year        85,171         6,433
# 7       Brand Warranty of 1 Year        85,171         6,433
# 8       Brand Warranty of 1 Year        85,171         6,433
# 9       Brand Warranty of 1 Year        85,171         6,433
# 10      Brand Warranty of 1 Year        85,171         6,433
# 11      Brand Warranty of 1 Year        85,171         6,433
# 12      Brand Warranty of 1 Year      1,45,512        16,305
# 13     Brand Warranty for 1 Year        85,171         6,433
# 14     Brand Warranty for 1 Year        85,171         6,433
# 15     Brand Warranty for 1 Year        85,171         6,433
# 16     Brand Warranty for 1 Year        85,171         6,433
# 17     Brand Warranty for 1 Year        85,171         6,433
# 18     Brand Warranty for 1 Year        85,171         6,433
# 19      Brand Warranty of 1 Year        85,171         6,433
# 20     Brand Warranty for 1 Year        85,171         6,433
# 21     Brand Warranty for 1 Year        85,171         6,433
# 22     Brand Warranty for 1 Year        85,171         6,433
# 23     Brand Warranty for 1 Year        85,171         6,433
# 24      Brand Warranty of 1 Year        85,171         6,433
# 25      Brand Warranty of 1 Year        85,171         6,433
# 26      Brand Warranty of 1 Year        85,171         6,433
# 27      Brand Warranty of 1 Year        85,171         6,433
# 28      Brand Warranty of 1 Year        85,171         6,433
# 29      Brand Warranty of 1 Year        85,171         6,433
# 30      Brand Warranty of 1 Year        85,171         6,433
# 31      Brand Warranty of 1 Year        85,171         6,433
# 32      Brand Warranty of 1 Year        85,171         6,433
# 33      Brand Warranty of 1 Year        85,171         6,433
# 34      Brand Warranty of 1 Year        85,171         6,433
# 35      Brand Warranty of 1 Year        85,171         6,433
# 36  1 Year Manufacturer Warranty      1,45,512        16,305
# 37     Brand Warranty for 1 Year        85,171         6,433
# 38     Brand Warranty for 1 Year        85,171         6,433
# 39     Brand Warranty for 1 Year        85,171         6,433
# 40     Brand Warranty for 1 Year        85,171         6,433
# 41     Brand Warranty for 1 Year        85,171         6,433
# 42     Brand Warranty for 1 Year        85,171         6,433
# 43     Brand Warranty for 1 Year        85,171         6,433
# 44      Brand Warranty of 1 Year        85,171         6,433
# 45     Brand Warranty for 1 Year        85,171         6,433
# 46     Brand Warranty for 1 Year        85,171         6,433
# 47     Brand Warranty for 1 Year        85,171         6,433
#
#                                              Features
# 0   64 GB ROM,15.49 cm (6.1 inch) Liquid Retina HD...
# 1   64 GB ROM,15.49 cm (6.1 inch) Liquid Retina HD...
# 2   128 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 3   64 GB ROM,15.49 cm (6.1 inch) Liquid Retina HD...
# 4   128 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 5   64 GB ROM,15.49 cm (6.1 inch) Liquid Retina HD...
# 6   128 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 7   128 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 8   64 GB ROM,15.49 cm (6.1 inch) Liquid Retina HD...
# 9   128 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 10  64 GB ROM,15.49 cm (6.1 inch) Liquid Retina HD...
# 11  128 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 12  32 GB ROM,11.94 cm (4.7 inch) Retina HD Displa...
# 13  64 GB ROM,15.49 cm (6.1 inch) Liquid Retina HD...
# 14  64 GB ROM,15.49 cm (6.1 inch) Liquid Retina HD...
# 15  256 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 16  128 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 17  256 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 18  256 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 19  256 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 20  128 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 21  64 GB ROM,15.49 cm (6.1 inch) Liquid Retina HD...
# 22  128 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 23  128 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 24  64 GB ROM,15.49 cm (6.1 inch) Liquid Retina HD...
# 25  64 GB ROM,15.49 cm (6.1 inch) Liquid Retina HD...
# 26  64 GB ROM,15.49 cm (6.1 inch) Liquid Retina HD...
# 27  128 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 28  64 GB ROM,15.49 cm (6.1 inch) Liquid Retina HD...
# 29  128 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 30  64 GB ROM,15.49 cm (6.1 inch) Liquid Retina HD...
# 31  128 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 32  128 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 33  128 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 34  64 GB ROM,15.49 cm (6.1 inch) Liquid Retina HD...
# 35  128 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 36  16 GB ROM,11.94 cm (4.7 inch) Retina HD Displa...
# 37  64 GB ROM,15.49 cm (6.1 inch) Liquid Retina HD...
# 38  64 GB ROM,15.49 cm (6.1 inch) Liquid Retina HD...
# 39  64 GB ROM,15.49 cm (6.1 inch) Liquid Retina HD...
# 40  256 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 41  128 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 42  256 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 43  256 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 44  256 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 45  128 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 46  128 GB ROM,15.49 cm (6.1 inch) Liquid Retina H...
# 47  64 GB ROM,15.49 cm (6.1 inch) Liquid Retina HD...

# %%
data.to_csv('C:/Users/Saran/Documents/Abinesh Files/VAC - Data Analytics With Python/Assignment - 1.csv')
